# %% [markdown]
# <a href="https://colab.research.google.com/github/kmart138/labJournal2/blob/main/session9Q.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.random.uniform(0, 1, 1000)

plt.figure()
plt.hist(data, bins=100, edgecolor='black')
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram of Uniformly Distributed Random Numbers")
plt.grid(True)
plt.savefig("uniform_histogram.pdf")
plt.show()

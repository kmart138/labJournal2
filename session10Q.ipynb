# %% [markdown]
# <a href="https://colab.research.google.com/github/kmart138/labJournal2/blob/main/session10Q.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.random.exponential(scale=1.0, size=1000)

plt.figure()
plt.hist(data, bins=100, edgecolor='black')
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram of Exponentially Distributed Random Numbers")
plt.grid(True)
plt.savefig("exponential_histogram.pdf")
plt.show()
